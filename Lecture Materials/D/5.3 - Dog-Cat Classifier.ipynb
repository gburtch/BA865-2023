# %% [markdown]
# # Import Our Data

# %% [markdown]
# Load the data to your Google Drive. Then you can mount your drive and access the folder wherever you saved it.

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Here, we are using the image_dataset_from_directory utilty, which reads images from a file path into a tf.Dataset object. This is much more memory efficient than reading images into lists! The dataset is already organized into training, test, and validation splits on my file system. The labels are inferred from the folder names.

# %%
from tensorflow.keras.utils import image_dataset_from_directory

base_dir = "drive/My Drive/Teaching/Courses/BA 865/BA865-2023/Lecture Materials/D/datasets/dogs-vs-cats"
  
train_dataset = image_dataset_from_directory(
    base_dir + "/train/",
    image_size=(180, 180),
    batch_size=32)
validation_dataset = image_dataset_from_directory(
    base_dir + "/validation/",
    image_size=(180, 180),
    batch_size=32)
test_dataset = image_dataset_from_directory(
    base_dir + "/test/",
    image_size=(180, 180),
    batch_size=32)
# Out:
# Found 765 files belonging to 2 classes.
# Found 400 files belonging to 2 classes.
# Found 798 files belonging to 2 classes.

# %%
for data_batch, labels_batch in train_dataset:
     print("data batch shape:", data_batch.shape)
     print("labels batch shape:", labels_batch.shape)
     break
# Out:
# data batch shape: (32, 180, 180, 3)
# labels batch shape: (32,)

# %% [markdown]
# # Define Our Model

# %%
from tensorflow import keras 
from tensorflow.keras import layers
  
inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1./255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 178, 178, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 89, 89, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 87, 87, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 43, 43, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 41, 41, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 20, 20, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 18, 18, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 9, 9, 256)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 7, 7, 256)         590080
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 1)                 12545
#
# =================================================================
# Total params: 991,041
# Trainable params: 991,041
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# We have a binary outcome variable, hence our use of Sigmoid activation on the output layer. We will use binary cross-entropy loss as our loss function. And, we'll monitor accuracy.

# %%
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %% [markdown]
# This callback we are defining will write the current best model (and parameter values) to disk, based on minimum validation loss.

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="drive/My Drive/Teaching/Courses/BA 865/BA865-2023/Lecture Materials/D/convnet_from_scratch.keras",
        save_best_only=True,
        monitor="val_loss")
]

# %% [markdown]
# Note that batch size isn't defined here, because we defined it when we first created the tf.Dataset object! This Dataset object is an iterator, containing batches of images.

# %%
history = model.fit(
    train_dataset,
    epochs=20,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 38s 1s/step - loss: 0.7072 - accuracy: 0.5150 - val_loss: 0.6924 - val_accuracy: 0.5700
# Epoch 2/20
# 24/24 [==============================] - 1s 35ms/step - loss: 0.7088 - accuracy: 0.5490 - val_loss: 0.6916 - val_accuracy: 0.5050
# Epoch 3/20
# 24/24 [==============================] - 1s 35ms/step - loss: 0.6912 - accuracy: 0.5268 - val_loss: 0.6858 - val_accuracy: 0.5375
# Epoch 4/20
# 24/24 [==============================] - 1s 33ms/step - loss: 0.6870 - accuracy: 0.5464 - val_loss: 0.7046 - val_accuracy: 0.5050
# Epoch 5/20
# 24/24 [==============================] - 1s 45ms/step - loss: 0.6818 - accuracy: 0.5464 - val_loss: 0.6673 - val_accuracy: 0.5725
# Epoch 6/20
# 24/24 [==============================] - 1s 35ms/step - loss: 0.6681 - accuracy: 0.6209 - val_loss: 0.6567 - val_accuracy: 0.6350
# Epoch 7/20
# 24/24 [==============================] - 1s 33ms/step - loss: 0.6369 - accuracy: 0.6575 - val_loss: 0.6747 - val_accuracy: 0.6150
# Epoch 8/20
# 24/24 [==============================] - 1s 32ms/step - loss: 0.5991 - accuracy: 0.6915 - val_loss: 0.6693 - val_accuracy: 0.6175
# Epoch 9/20
# 24/24 [==============================] - 1s 35ms/step - loss: 0.5878 - accuracy: 0.6876 - val_loss: 0.6072 - val_accuracy: 0.6775
# Epoch 10/20
# 24/24 [==============================] - 1s 32ms/step - loss: 0.5458 - accuracy: 0.7203 - val_loss: 0.6469 - val_accuracy: 0.6600
# Epoch 11/20
# 24/24 [==============================] - 1s 37ms/step - loss: 0.5233 - accuracy: 0.7451 - val_loss: 0.5934 - val_accuracy: 0.6550
# Epoch 12/20
# 24/24 [==============================] - 1s 33ms/step - loss: 0.4957 - accuracy: 0.7595 - val_loss: 0.6414 - val_accuracy: 0.6625
# Epoch 13/20
# 24/24 [==============================] - 1s 32ms/step - loss: 0.4622 - accuracy: 0.7660 - val_loss: 0.6300 - val_accuracy: 0.6900
# Epoch 14/20
# 24/24 [==============================] - 1s 33ms/step - loss: 0.4410 - accuracy: 0.7987 - val_loss: 0.6327 - val_accuracy: 0.7050
# Epoch 15/20
# 24/24 [==============================] - 1s 33ms/step - loss: 0.3846 - accuracy: 0.8275 - val_loss: 0.6661 - val_accuracy: 0.6925
# Epoch 16/20
# 24/24 [==============================] - 1s 33ms/step - loss: 0.3724 - accuracy: 0.8418 - val_loss: 0.6941 - val_accuracy: 0.6650
# Epoch 17/20
# 24/24 [==============================] - 1s 32ms/step - loss: 0.3270 - accuracy: 0.8575 - val_loss: 0.8117 - val_accuracy: 0.6750
# Epoch 18/20
# 24/24 [==============================] - 1s 33ms/step - loss: 0.2786 - accuracy: 0.8967 - val_loss: 0.9132 - val_accuracy: 0.6975
# Epoch 19/20
# 24/24 [==============================] - 1s 32ms/step - loss: 0.2436 - accuracy: 0.8928 - val_loss: 0.9536 - val_accuracy: 0.6475
# Epoch 20/20
# 24/24 [==============================] - 1s 32ms/step - loss: 0.1924 - accuracy: 0.9268 - val_loss: 1.0604 - val_accuracy: 0.6750

# %% [markdown]
# And we can plot loss over training iterations...

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['val_accuracy'],c="b")
plt.plot(history.history['accuracy'],c="r")
plt.legend(['Validation Acc','Training Acc'])
plt.show()

# %% [markdown]
# Note that we reach > 65% accuracy pretty quickly without much effort, but it plateaus there.

# %%
test_model = keras.models.load_model("drive/My Drive/Teaching/Courses/BA 865/BA865-2023/Lecture Materials/D/convnet_from_scratch.keras")
test_loss, test_acc = test_model.evaluate(test_dataset) 
print(f"Test accuracy: {test_acc}")
# Out:
# 25/25 [==============================] - 25s 648ms/step - loss: 0.5557 - accuracy: 0.7343
# Test accuracy: 0.7343358397483826

# %% [markdown]
# # Data Augmentation

# %% [markdown]
# To stave off the overfitting, we will first start by augmenting our dataset. This is a simple way to do it in a Sequential model, by adding a data augmentation layer. This step in our model will randomly mess with the data at each pass, flipping, rotating and zooming each image.

# %%
data_augmentation = keras.Sequential([
   layers.RandomFlip("horizontal"),
   layers.RandomRotation(0.1),
   layers.RandomZoom(0.2),
])

# %% [markdown]
# You'll see that adding the aaumentation layer gets us another 5% bump in the validation accuracy of our model, up to about 72% fairly consistently. Note that we do a bit worse than the textbook claims, because we are using less data (I kept about 40% of the sample the book was working with).

# %%
from tensorflow import keras 
from tensorflow.keras import layers
  
inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = layers.Rescaling(1./255)(x)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# We are making a different callback so we don't overwrite our last model (we might want to compare them)
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch_with_augmentation.keras",
        save_best_only=True,
        monitor="val_loss")
]

# And let's fit the model.
history = model.fit(
    train_dataset,
    epochs=100,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 3s 41ms/step - loss: 0.6978 - accuracy: 0.4758 - val_loss: 0.6926 - val_accuracy: 0.5000
# Epoch 2/100
# 24/24 [==============================] - 1s 35ms/step - loss: 0.6977 - accuracy: 0.5242 - val_loss: 0.6912 - val_accuracy: 0.5000
# Epoch 3/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.6941 - accuracy: 0.5346 - val_loss: 0.6917 - val_accuracy: 0.5000
# Epoch 4/100
# 24/24 [==============================] - 1s 35ms/step - loss: 0.6936 - accuracy: 0.5268 - val_loss: 0.6884 - val_accuracy: 0.5825
# Epoch 5/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.6875 - accuracy: 0.5791 - val_loss: 0.6787 - val_accuracy: 0.5200
# Epoch 6/100
# 24/24 [==============================] - 1s 36ms/step - loss: 0.6731 - accuracy: 0.6105 - val_loss: 0.6410 - val_accuracy: 0.6550
# Epoch 7/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.6674 - accuracy: 0.6235 - val_loss: 0.7398 - val_accuracy: 0.5125
# Epoch 8/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.6440 - accuracy: 0.6314 - val_loss: 0.6431 - val_accuracy: 0.6350
# Epoch 9/100
# 24/24 [==============================] - 1s 35ms/step - loss: 0.6546 - accuracy: 0.6405 - val_loss: 0.6362 - val_accuracy: 0.6275
# Epoch 10/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.6294 - accuracy: 0.6536 - val_loss: 0.6145 - val_accuracy: 0.6700
# Epoch 11/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.6336 - accuracy: 0.6471 - val_loss: 0.7058 - val_accuracy: 0.5825
# Epoch 12/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.6227 - accuracy: 0.6562 - val_loss: 0.6670 - val_accuracy: 0.5750
# Epoch 13/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.6144 - accuracy: 0.6667 - val_loss: 0.6168 - val_accuracy: 0.6500
# Epoch 14/100
# 24/24 [==============================] - 1s 35ms/step - loss: 0.6012 - accuracy: 0.6719 - val_loss: 0.5713 - val_accuracy: 0.6775
# Epoch 15/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.5548 - accuracy: 0.7007 - val_loss: 0.7101 - val_accuracy: 0.6300
# Epoch 16/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.5884 - accuracy: 0.6863 - val_loss: 0.6234 - val_accuracy: 0.6550
# Epoch 17/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.5924 - accuracy: 0.6889 - val_loss: 0.6155 - val_accuracy: 0.6700
# Epoch 18/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.5492 - accuracy: 0.7124 - val_loss: 0.7439 - val_accuracy: 0.5850
# Epoch 19/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.5662 - accuracy: 0.6980 - val_loss: 0.8522 - val_accuracy: 0.5850
# Epoch 20/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.5640 - accuracy: 0.7098 - val_loss: 0.6190 - val_accuracy: 0.6800
# Epoch 21/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.5357 - accuracy: 0.7163 - val_loss: 0.7210 - val_accuracy: 0.5925
# Epoch 22/100
# 24/24 [==============================] - 1s 32ms/step - loss: 0.5464 - accuracy: 0.7203 - val_loss: 0.6557 - val_accuracy: 0.6425
# Epoch 23/100
# 24/24 [==============================] - 1s 35ms/step - loss: 0.5658 - accuracy: 0.7150 - val_loss: 0.5635 - val_accuracy: 0.7100
# Epoch 24/100
# 24/24 [==============================] - 1s 32ms/step - loss: 0.5223 - accuracy: 0.7216 - val_loss: 0.5894 - val_accuracy: 0.6800
# Epoch 25/100
# 24/24 [==============================] - 1s 32ms/step - loss: 0.5293 - accuracy: 0.7281 - val_loss: 0.5650 - val_accuracy: 0.7050
# Epoch 26/100
# 24/24 [==============================] - 1s 35ms/step - loss: 0.5006 - accuracy: 0.7569 - val_loss: 0.5517 - val_accuracy: 0.7150
# Epoch 27/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.5039 - accuracy: 0.7503 - val_loss: 0.5658 - val_accuracy: 0.6975
# Epoch 28/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.5102 - accuracy: 0.7542 - val_loss: 0.5563 - val_accuracy: 0.7375
# Epoch 29/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.5006 - accuracy: 0.7647 - val_loss: 0.5442 - val_accuracy: 0.7225
# Epoch 30/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.4857 - accuracy: 0.7686 - val_loss: 0.5540 - val_accuracy: 0.7125
# Epoch 31/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.4801 - accuracy: 0.7595 - val_loss: 0.6059 - val_accuracy: 0.6950
# Epoch 32/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.4718 - accuracy: 0.7595 - val_loss: 0.6461 - val_accuracy: 0.7200
# Epoch 33/100
# 24/24 [==============================] - 1s 35ms/step - loss: 0.4496 - accuracy: 0.8013 - val_loss: 0.7125 - val_accuracy: 0.6900
# Epoch 34/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.4481 - accuracy: 0.7778 - val_loss: 0.8700 - val_accuracy: 0.6600
# Epoch 35/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.4465 - accuracy: 0.7948 - val_loss: 0.5375 - val_accuracy: 0.7400
# Epoch 36/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.4456 - accuracy: 0.7948 - val_loss: 0.6125 - val_accuracy: 0.7450
# Epoch 37/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.4264 - accuracy: 0.8026 - val_loss: 0.5746 - val_accuracy: 0.7425
# Epoch 38/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.4494 - accuracy: 0.7987 - val_loss: 0.5537 - val_accuracy: 0.7300
# Epoch 39/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.4020 - accuracy: 0.8052 - val_loss: 0.5616 - val_accuracy: 0.7225
# Epoch 40/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.4300 - accuracy: 0.8157 - val_loss: 0.5873 - val_accuracy: 0.7375
# Epoch 41/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.3937 - accuracy: 0.8261 - val_loss: 0.8503 - val_accuracy: 0.6175
# Epoch 42/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.4100 - accuracy: 0.8105 - val_loss: 0.5903 - val_accuracy: 0.7350
# Epoch 43/100
# 24/24 [==============================] - 1s 32ms/step - loss: 0.4027 - accuracy: 0.8144 - val_loss: 0.8432 - val_accuracy: 0.6625
# Epoch 44/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.3931 - accuracy: 0.8209 - val_loss: 0.6506 - val_accuracy: 0.7550
# Epoch 45/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.4323 - accuracy: 0.8000 - val_loss: 0.7941 - val_accuracy: 0.7175
# Epoch 46/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.3365 - accuracy: 0.8510 - val_loss: 0.6938 - val_accuracy: 0.7425
# Epoch 47/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.3756 - accuracy: 0.8301 - val_loss: 1.1252 - val_accuracy: 0.6900
# Epoch 48/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.3703 - accuracy: 0.8327 - val_loss: 0.6916 - val_accuracy: 0.7275
# Epoch 49/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.3583 - accuracy: 0.8562 - val_loss: 0.7199 - val_accuracy: 0.7600
# Epoch 50/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.3487 - accuracy: 0.8444 - val_loss: 0.6082 - val_accuracy: 0.7625
# Epoch 51/100
# 24/24 [==============================] - 1s 32ms/step - loss: 0.3459 - accuracy: 0.8471 - val_loss: 0.6513 - val_accuracy: 0.7300
# Epoch 52/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.3482 - accuracy: 0.8405 - val_loss: 0.6156 - val_accuracy: 0.7525
# Epoch 53/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.3291 - accuracy: 0.8601 - val_loss: 0.7701 - val_accuracy: 0.7425
# Epoch 54/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.3264 - accuracy: 0.8719 - val_loss: 0.6510 - val_accuracy: 0.7500
# Epoch 55/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.3002 - accuracy: 0.8758 - val_loss: 0.7156 - val_accuracy: 0.7725
# Epoch 56/100
# 24/24 [==============================] - 1s 32ms/step - loss: 0.2975 - accuracy: 0.8693 - val_loss: 0.6631 - val_accuracy: 0.7650
# Epoch 57/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.3019 - accuracy: 0.8719 - val_loss: 0.8911 - val_accuracy: 0.6950
# Epoch 58/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.3043 - accuracy: 0.8614 - val_loss: 0.6888 - val_accuracy: 0.7500
# Epoch 59/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.2715 - accuracy: 0.8941 - val_loss: 0.7560 - val_accuracy: 0.7500
# Epoch 60/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.3281 - accuracy: 0.8902 - val_loss: 0.6097 - val_accuracy: 0.7725
# Epoch 61/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.2742 - accuracy: 0.8889 - val_loss: 0.7615 - val_accuracy: 0.7700
# Epoch 62/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.2623 - accuracy: 0.9059 - val_loss: 1.0075 - val_accuracy: 0.7425
# Epoch 63/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.2790 - accuracy: 0.8967 - val_loss: 0.7991 - val_accuracy: 0.7350
# Epoch 64/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.2784 - accuracy: 0.8837 - val_loss: 0.6467 - val_accuracy: 0.7550
# Epoch 65/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.2538 - accuracy: 0.9033 - val_loss: 0.7258 - val_accuracy: 0.7675
# Epoch 66/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.2221 - accuracy: 0.9098 - val_loss: 0.8119 - val_accuracy: 0.7450
# Epoch 67/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.2510 - accuracy: 0.8941 - val_loss: 1.0296 - val_accuracy: 0.7225
# Epoch 68/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.2535 - accuracy: 0.8980 - val_loss: 0.7863 - val_accuracy: 0.7600
# Epoch 69/100
# 24/24 [==============================] - 1s 35ms/step - loss: 0.2387 - accuracy: 0.9020 - val_loss: 1.0218 - val_accuracy: 0.7500
# Epoch 70/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.2243 - accuracy: 0.9085 - val_loss: 0.8019 - val_accuracy: 0.7450
# Epoch 71/100
# 24/24 [==============================] - 1s 35ms/step - loss: 0.2223 - accuracy: 0.9294 - val_loss: 0.8196 - val_accuracy: 0.7450
# Epoch 72/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.2172 - accuracy: 0.9203 - val_loss: 0.9515 - val_accuracy: 0.7500
# Epoch 73/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.2389 - accuracy: 0.9072 - val_loss: 0.9688 - val_accuracy: 0.7350
# Epoch 74/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.1788 - accuracy: 0.9229 - val_loss: 0.8275 - val_accuracy: 0.7875
# Epoch 75/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.2243 - accuracy: 0.9137 - val_loss: 0.7852 - val_accuracy: 0.7725
# Epoch 76/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.1637 - accuracy: 0.9438 - val_loss: 1.2107 - val_accuracy: 0.7425
# Epoch 77/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.2445 - accuracy: 0.8915 - val_loss: 0.8488 - val_accuracy: 0.7750
# Epoch 78/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.1956 - accuracy: 0.9268 - val_loss: 0.9135 - val_accuracy: 0.7675
# Epoch 79/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.1877 - accuracy: 0.9268 - val_loss: 0.7225 - val_accuracy: 0.7700
# Epoch 80/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.1712 - accuracy: 0.9373 - val_loss: 0.9730 - val_accuracy: 0.7725
# Epoch 81/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.1476 - accuracy: 0.9412 - val_loss: 1.3298 - val_accuracy: 0.7050
# Epoch 82/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.1853 - accuracy: 0.9373 - val_loss: 0.9705 - val_accuracy: 0.7525
# Epoch 83/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.2124 - accuracy: 0.9163 - val_loss: 0.9983 - val_accuracy: 0.7700
# Epoch 84/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.1466 - accuracy: 0.9386 - val_loss: 0.8501 - val_accuracy: 0.7850
# Epoch 85/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.1681 - accuracy: 0.9425 - val_loss: 1.0894 - val_accuracy: 0.7500
# Epoch 86/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.1871 - accuracy: 0.9229 - val_loss: 1.4799 - val_accuracy: 0.7175
# Epoch 87/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.1945 - accuracy: 0.9268 - val_loss: 0.8252 - val_accuracy: 0.7800
# Epoch 88/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.1625 - accuracy: 0.9399 - val_loss: 1.1867 - val_accuracy: 0.7075
# Epoch 89/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.1218 - accuracy: 0.9529 - val_loss: 0.9492 - val_accuracy: 0.7775
# Epoch 90/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.2202 - accuracy: 0.9072 - val_loss: 0.9703 - val_accuracy: 0.7425
# Epoch 91/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.1330 - accuracy: 0.9490 - val_loss: 0.9529 - val_accuracy: 0.7825
# Epoch 92/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.1804 - accuracy: 0.9503 - val_loss: 0.9411 - val_accuracy: 0.7725
# Epoch 93/100
# 24/24 [==============================] - 1s 32ms/step - loss: 0.1337 - accuracy: 0.9516 - val_loss: 1.0545 - val_accuracy: 0.7600
# Epoch 94/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.1398 - accuracy: 0.9503 - val_loss: 1.0993 - val_accuracy: 0.7675
# Epoch 95/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.1400 - accuracy: 0.9386 - val_loss: 1.0759 - val_accuracy: 0.7775
# Epoch 96/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.1395 - accuracy: 0.9425 - val_loss: 1.5412 - val_accuracy: 0.7525
# Epoch 97/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.1504 - accuracy: 0.9516 - val_loss: 1.2246 - val_accuracy: 0.7225
# Epoch 98/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.1630 - accuracy: 0.9399 - val_loss: 1.1054 - val_accuracy: 0.7700
# Epoch 99/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.1171 - accuracy: 0.9542 - val_loss: 1.1373 - val_accuracy: 0.7525
# Epoch 100/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.1043 - accuracy: 0.9582 - val_loss: 1.3281 - val_accuracy: 0.7775

# %% [markdown]
# Let's plot the accuracy over training again...

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['val_accuracy'],c="b")
plt.plot(history.history['accuracy'],c="r")
plt.legend(['Validation Acc','Training Acc'])
plt.show()

# %% [markdown]
# And let's check the test accuracy.

# %%
test_model = keras.models.load_model("convnet_from_scratch_with_augmentation.keras")
test_loss, test_acc = test_model.evaluate(test_dataset) 
print(f"Test accuracy: {test_acc}")
# Out:
# 25/25 [==============================] - 1s 16ms/step - loss: 0.5537 - accuracy: 0.7155
# Test accuracy: 0.7155388593673706

# %% [markdown]
# # Feature Extraction from a Pre-Trained Model: VGG16

# %% [markdown]
# Now we are going to load a pre-trained model, to leverage its convolutional base for our task. Note that the convolutional base, alone, is about 15 million parameters.

# %%
conv_base = keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False, # Throw away the densely connected layer at the end.
    input_shape=(180, 180, 3)) # Optional - just for model.summary() call.

conv_base.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 180, 180, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 180, 180, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 90, 90, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 90, 90, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 90, 90, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 45, 45, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 45, 45, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 45, 45, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 45, 45, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 22, 22, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 22, 22, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 22, 22, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 22, 22, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 11, 11, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 5, 5, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Now we run our training, validation, and test data images through the convolutional base, get the feature representations of each according to VGG, and then store them alongside their cat/dog labels.

# %%
import numpy as np
  
def get_features_and_labels(dataset):
    all_features = []
    all_labels = []
    for images, labels in dataset:
        preprocessed_images = keras.applications.vgg16.preprocess_input(images)
        features = conv_base.predict(preprocessed_images)
        all_features.append(features)
        all_labels.append(labels)
    return np.concatenate(all_features), np.concatenate(all_labels)
  
train_features, train_labels =  get_features_and_labels(train_dataset)
val_features, val_labels =  get_features_and_labels(validation_dataset)
test_features, test_labels =  get_features_and_labels(test_dataset)
# Out:
# 1/1 [==============================] - 1s 941ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 1s 732ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 427ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 1s 634ms/step

# %% [markdown]
# Here, you can see the dimensionality of the features associated with a single image. The VGG output from the convolutional layer comprises of 512 feature-specific feature maps, that are each 5x5 in dimensionality.

# %%
print(train_features[0].shape)
# Out:
# (5, 5, 512)

# %% [markdown]
# So, now we are going to define a new model that sits on the end of the VGG convolutional layer. It'll take those 512 featuremaps, flatten them, pass them to a Dense layer of 256 nodes, and then feed to a one-node sigmoid output (with some Dropout). This model will fit extremely quickly, and it's accuracy will be way higher, approaching 97%

# %%
inputs = keras.Input(shape=(5, 5, 512))
x = layers.Flatten()(inputs)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])
  
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="feature_extraction.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_features, train_labels,
    epochs=20,
    validation_data=(val_features, val_labels),
    callbacks=callbacks)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 1s 14ms/step - loss: 25.0621 - accuracy: 0.8889 - val_loss: 16.3678 - val_accuracy: 0.9225
# Epoch 2/20
# 24/24 [==============================] - 0s 8ms/step - loss: 2.6978 - accuracy: 0.9778 - val_loss: 3.7804 - val_accuracy: 0.9575
# Epoch 3/20
# 24/24 [==============================] - 0s 5ms/step - loss: 0.8778 - accuracy: 0.9908 - val_loss: 19.4315 - val_accuracy: 0.9225
# Epoch 4/20
# 24/24 [==============================] - 0s 5ms/step - loss: 2.0152 - accuracy: 0.9804 - val_loss: 7.3758 - val_accuracy: 0.9525
# Epoch 5/20
# 24/24 [==============================] - 0s 5ms/step - loss: 0.5113 - accuracy: 0.9961 - val_loss: 21.9753 - val_accuracy: 0.9225
# Epoch 6/20
# 24/24 [==============================] - 0s 5ms/step - loss: 1.1085 - accuracy: 0.9882 - val_loss: 8.7881 - val_accuracy: 0.9400
# Epoch 7/20
# 24/24 [==============================] - 0s 5ms/step - loss: 0.5839 - accuracy: 0.9922 - val_loss: 11.1004 - val_accuracy: 0.9500
# Epoch 8/20
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0451 - accuracy: 0.9987 - val_loss: 7.8264 - val_accuracy: 0.9475
# Epoch 9/20
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2773 - accuracy: 0.9961 - val_loss: 15.5723 - val_accuracy: 0.9450
# Epoch 10/20
# 24/24 [==============================] - 0s 5ms/step - loss: 0.5834 - accuracy: 0.9974 - val_loss: 13.8463 - val_accuracy: 0.9400
# Epoch 11/20
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0032 - accuracy: 0.9987 - val_loss: 10.2286 - val_accuracy: 0.9450
# Epoch 12/20
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3782 - accuracy: 0.9948 - val_loss: 11.6788 - val_accuracy: 0.9300
# Epoch 13/20
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2828 - accuracy: 0.9974 - val_loss: 11.5743 - val_accuracy: 0.9375
# Epoch 14/20
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2874 - accuracy: 0.9987 - val_loss: 23.7058 - val_accuracy: 0.9400
# Epoch 15/20
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2910 - accuracy: 0.9974 - val_loss: 16.1061 - val_accuracy: 0.9175
# Epoch 16/20
# 24/24 [==============================] - 0s 6ms/step - loss: 0.3109 - accuracy: 0.9961 - val_loss: 12.2269 - val_accuracy: 0.9450
# Epoch 17/20
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4260 - accuracy: 0.9948 - val_loss: 18.7847 - val_accuracy: 0.9450
# Epoch 18/20
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4813 - accuracy: 0.9961 - val_loss: 8.1225 - val_accuracy: 0.9525
# Epoch 19/20
# 24/24 [==============================] - 0s 5ms/step - loss: 9.7257e-25 - accuracy: 1.0000 - val_loss: 8.1225 - val_accuracy: 0.9525
# Epoch 20/20
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0962 - accuracy: 0.9974 - val_loss: 7.5479 - val_accuracy: 0.9525

# %% [markdown]
# Plotting performance here...

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['val_accuracy'],c="b")
plt.plot(history.history['accuracy'],c="r")
plt.legend(['Validation Acc','Training Acc'])
plt.show()

# %% [markdown]
# And, evaluating performance on the test data.

# %%
test_model = keras.models.load_model("feature_extraction.keras")
test_loss, test_acc = test_model.evaluate(test_features,test_labels) 
print(f"Test accuracy: {test_acc}")
# Out:
# 25/25 [==============================] - 0s 2ms/step - loss: 4.3760 - accuracy: 0.9674
# Test accuracy: 0.9674185514450073

# %% [markdown]
# # Fine-Tuning from a Pre-Trained Model (with Data-Augmentation)

# %% [markdown]
# Here we are going to load the convolutional base, and actually use it inside our network (though we will freeze its parameters so we don't try to update them as we go, since that would ruin the model and add lots of computation time).

# %%
conv_base  = keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False)
conv_base.trainable = False # The convolutional layers won't be updatable; we just build on them using Functional API.

data_augmentation = keras.Sequential([
   layers.RandomFlip("horizontal"),
   layers.RandomRotation(0.1),
   layers.RandomZoom(0.2),
])
  
inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = keras.applications.vgg16.preprocess_input(x)
x = conv_base(x)
x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  sequential_1 (Sequential)   (None, 180, 180, 3)       0
#
#  tf.__operators__.getitem (S  (None, 180, 180, 3)      0
#  licingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda)  (None, 180, 180, 3)      0
#
#  vgg16 (Functional)          (None, None, None, 512)   14714688
#
#  flatten_3 (Flatten)         (None, 12800)             0
#
#  dense_4 (Dense)             (None, 256)               3277056
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 17,992,001
# Trainable params: 3,277,313
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# And now we can fit our model. This is slower because our forward pass has to go through the VGG convolutional base each iteration (rather than the one time we did when we used it for feature extraction.

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="fine_tuning_with_data_augmentation.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset, # Note we are back to working with our original training dataset.
    epochs=50,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 5s 152ms/step - loss: 26.2179 - accuracy: 0.8680 - val_loss: 4.9792 - val_accuracy: 0.9525
# Epoch 2/50
# 24/24 [==============================] - 4s 152ms/step - loss: 8.7457 - accuracy: 0.9307 - val_loss: 3.8188 - val_accuracy: 0.9600
# Epoch 3/50
# 24/24 [==============================] - 4s 138ms/step - loss: 4.5577 - accuracy: 0.9582 - val_loss: 7.1023 - val_accuracy: 0.9475
# Epoch 4/50
# 24/24 [==============================] - 4s 137ms/step - loss: 4.6958 - accuracy: 0.9569 - val_loss: 6.8383 - val_accuracy: 0.9425
# Epoch 5/50
# 24/24 [==============================] - 4s 140ms/step - loss: 4.3970 - accuracy: 0.9647 - val_loss: 8.7187 - val_accuracy: 0.9425
# Epoch 6/50
# 24/24 [==============================] - 4s 138ms/step - loss: 4.2388 - accuracy: 0.9595 - val_loss: 9.1188 - val_accuracy: 0.9525
# Epoch 7/50
# 24/24 [==============================] - 4s 142ms/step - loss: 2.5272 - accuracy: 0.9752 - val_loss: 12.3043 - val_accuracy: 0.9500
# Epoch 8/50
# 24/24 [==============================] - 4s 139ms/step - loss: 3.3198 - accuracy: 0.9699 - val_loss: 10.6709 - val_accuracy: 0.9325
# Epoch 9/50
# 24/24 [==============================] - 4s 139ms/step - loss: 4.1287 - accuracy: 0.9686 - val_loss: 15.9855 - val_accuracy: 0.9500
# Epoch 10/50
# 24/24 [==============================] - 4s 140ms/step - loss: 2.8200 - accuracy: 0.9752 - val_loss: 8.1346 - val_accuracy: 0.9475
# Epoch 11/50
# 24/24 [==============================] - 4s 140ms/step - loss: 2.8488 - accuracy: 0.9778 - val_loss: 10.1749 - val_accuracy: 0.9450
# Epoch 12/50
# 24/24 [==============================] - 4s 139ms/step - loss: 2.0171 - accuracy: 0.9765 - val_loss: 13.6410 - val_accuracy: 0.9475
# Epoch 13/50
# 24/24 [==============================] - 4s 137ms/step - loss: 2.0805 - accuracy: 0.9843 - val_loss: 15.7161 - val_accuracy: 0.9450
# Epoch 14/50
# 24/24 [==============================] - 4s 140ms/step - loss: 2.0524 - accuracy: 0.9778 - val_loss: 14.5743 - val_accuracy: 0.9475
# Epoch 15/50
# 24/24 [==============================] - 4s 138ms/step - loss: 1.8026 - accuracy: 0.9817 - val_loss: 9.4080 - val_accuracy: 0.9600
# Epoch 16/50
# 24/24 [==============================] - 4s 142ms/step - loss: 1.6963 - accuracy: 0.9817 - val_loss: 12.5194 - val_accuracy: 0.9450
# Epoch 17/50
# 24/24 [==============================] - 4s 141ms/step - loss: 0.5048 - accuracy: 0.9922 - val_loss: 15.0913 - val_accuracy: 0.9450
# Epoch 18/50
# 24/24 [==============================] - 4s 139ms/step - loss: 0.6684 - accuracy: 0.9895 - val_loss: 16.0389 - val_accuracy: 0.9500
# Epoch 19/50
# 24/24 [==============================] - 4s 139ms/step - loss: 1.8503 - accuracy: 0.9804 - val_loss: 13.8064 - val_accuracy: 0.9500
# Epoch 20/50
# 24/24 [==============================] - 4s 139ms/step - loss: 1.6153 - accuracy: 0.9869 - val_loss: 15.7618 - val_accuracy: 0.9500
# Epoch 21/50
# 24/24 [==============================] - 4s 137ms/step - loss: 0.5205 - accuracy: 0.9922 - val_loss: 13.4738 - val_accuracy: 0.9500
# Epoch 22/50
# 24/24 [==============================] - 4s 138ms/step - loss: 1.8195 - accuracy: 0.9869 - val_loss: 16.2688 - val_accuracy: 0.9475
# Epoch 23/50
# 24/24 [==============================] - 4s 137ms/step - loss: 0.5253 - accuracy: 0.9922 - val_loss: 17.9083 - val_accuracy: 0.9450
# Epoch 24/50
# 24/24 [==============================] - 4s 139ms/step - loss: 1.7023 - accuracy: 0.9895 - val_loss: 16.8871 - val_accuracy: 0.9475
# Epoch 25/50
# 24/24 [==============================] - 4s 139ms/step - loss: 0.3239 - accuracy: 0.9948 - val_loss: 21.6795 - val_accuracy: 0.9450
# Epoch 26/50
# 24/24 [==============================] - 4s 138ms/step - loss: 1.5713 - accuracy: 0.9869 - val_loss: 15.7296 - val_accuracy: 0.9550
# Epoch 27/50
# 24/24 [==============================] - 4s 140ms/step - loss: 1.2408 - accuracy: 0.9922 - val_loss: 14.3244 - val_accuracy: 0.9500
# Epoch 28/50
# 24/24 [==============================] - 4s 139ms/step - loss: 1.5976 - accuracy: 0.9869 - val_loss: 28.7253 - val_accuracy: 0.9425
# Epoch 29/50
# 24/24 [==============================] - 4s 139ms/step - loss: 0.9976 - accuracy: 0.9908 - val_loss: 14.0854 - val_accuracy: 0.9400
# Epoch 30/50
# 24/24 [==============================] - 4s 140ms/step - loss: 1.8491 - accuracy: 0.9869 - val_loss: 16.4107 - val_accuracy: 0.9525
# Epoch 31/50
# 24/24 [==============================] - 4s 139ms/step - loss: 1.0548 - accuracy: 0.9869 - val_loss: 11.9382 - val_accuracy: 0.9525
# Epoch 32/50
# 24/24 [==============================] - 4s 138ms/step - loss: 1.1035 - accuracy: 0.9882 - val_loss: 10.1816 - val_accuracy: 0.9500
# Epoch 33/50
# 24/24 [==============================] - 4s 139ms/step - loss: 2.2973 - accuracy: 0.9752 - val_loss: 10.5167 - val_accuracy: 0.9500
# Epoch 34/50
# 24/24 [==============================] - 4s 139ms/step - loss: 1.1693 - accuracy: 0.9895 - val_loss: 15.7934 - val_accuracy: 0.9550
# Epoch 35/50
# 24/24 [==============================] - 4s 138ms/step - loss: 1.3555 - accuracy: 0.9922 - val_loss: 13.6497 - val_accuracy: 0.9400
# Epoch 36/50
# 24/24 [==============================] - 4s 139ms/step - loss: 0.5766 - accuracy: 0.9908 - val_loss: 11.5039 - val_accuracy: 0.9450
# Epoch 37/50
# 24/24 [==============================] - 4s 138ms/step - loss: 0.4363 - accuracy: 0.9948 - val_loss: 10.9750 - val_accuracy: 0.9500
# Epoch 38/50
# 24/24 [==============================] - 4s 137ms/step - loss: 0.5592 - accuracy: 0.9961 - val_loss: 17.3332 - val_accuracy: 0.9550
# Epoch 39/50
# 24/24 [==============================] - 4s 138ms/step - loss: 0.0371 - accuracy: 0.9987 - val_loss: 10.6717 - val_accuracy: 0.9550
# Epoch 40/50
# 24/24 [==============================] - 4s 138ms/step - loss: 0.9349 - accuracy: 0.9856 - val_loss: 10.2219 - val_accuracy: 0.9475
# Epoch 41/50
# 24/24 [==============================] - 4s 140ms/step - loss: 0.2462 - accuracy: 0.9974 - val_loss: 10.8550 - val_accuracy: 0.9475
# Epoch 42/50
# 24/24 [==============================] - 4s 139ms/step - loss: 1.0208 - accuracy: 0.9922 - val_loss: 11.0028 - val_accuracy: 0.9500
# Epoch 43/50
# 24/24 [==============================] - 4s 137ms/step - loss: 0.3931 - accuracy: 0.9935 - val_loss: 13.3594 - val_accuracy: 0.9550
# Epoch 44/50
# 24/24 [==============================] - 4s 137ms/step - loss: 1.0009 - accuracy: 0.9922 - val_loss: 12.9342 - val_accuracy: 0.9575
# Epoch 45/50
# 24/24 [==============================] - 4s 138ms/step - loss: 0.1937 - accuracy: 0.9974 - val_loss: 13.9216 - val_accuracy: 0.9500
# Epoch 46/50
# 24/24 [==============================] - 4s 139ms/step - loss: 0.6439 - accuracy: 0.9908 - val_loss: 14.7264 - val_accuracy: 0.9275
# Epoch 47/50
# 24/24 [==============================] - 4s 137ms/step - loss: 0.9293 - accuracy: 0.9908 - val_loss: 11.5633 - val_accuracy: 0.9500
# Epoch 48/50
# 24/24 [==============================] - 4s 137ms/step - loss: 0.0761 - accuracy: 0.9935 - val_loss: 11.3786 - val_accuracy: 0.9600
# Epoch 49/50
# 24/24 [==============================] - 4s 138ms/step - loss: 0.3250 - accuracy: 0.9948 - val_loss: 10.9048 - val_accuracy: 0.9600
# Epoch 50/50
# 24/24 [==============================] - 4s 138ms/step - loss: 0.2567 - accuracy: 0.9961 - val_loss: 10.4500 - val_accuracy: 0.9550
