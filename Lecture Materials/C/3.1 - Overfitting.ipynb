# %% [markdown]
# #**Extreme Overfitting Example**

# %% [markdown]
# I'm going to simulate a set of random images and their associated labels. I want you to then fit a neural network to the random data. Finally, report how accurate the model is on the training data, and visualize training accuracy across epochs.

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from tensorflow import keras 
from tensorflow.keras import layers
import matplotlib.pyplot as plt
from PIL import Image as im

# Let's synthesize 20,000 images comprised of random pixel values.
train_images_random = np.random.random((5000, 28,28))
df = pd.DataFrame(train_images_random.reshape(-1)) #-1 is a wildcard; it'll guess what shape I want, and by default give a vector back.
print(f'Descriptive statistics for the training data:\n{df.describe()}\n')

# And let's make-up labels for them. 
train_labels_random = np.floor(np.random.random(5000)*10)
print(f'The first ten labels are {train_labels_random[:10]}\n')

# Here's what the first picture looks like.
plt.imshow(train_images_random[0],cmap=plt.cm.binary)
plt.show()

# Let's first convert each pixel matrix into a vector. 
train_images_random = train_images_random.reshape(5000,28*28)
train_labels_random = train_labels_random.reshape(5000,1)
print(train_images_random.shape)
print(train_labels_random.shape)
# Out:
# Descriptive statistics for the training data:
#                   0
# count  3.920000e+06
# mean   5.001274e-01
# std    2.886307e-01
# min    2.937359e-07
# 25%    2.502785e-01
# 50%    5.001303e-01
# 75%    7.501524e-01
# max    9.999999e-01
#
# The first ten labels are [9. 8. 1. 8. 4. 2. 9. 2. 8. 2.]
# (5000, 784)
# (5000, 1)

# %% [markdown]
# Now we will use the simulated data and fit a sequential Keras model that has 512 units in the first layer, with a Relu activation, and then the output layer.

# %%
# Setup your model topology here using the Sequential API.
model = keras.Sequential([
      layers.Dense(512,activation="relu"),
      layers.Dense(10, activation="softmax")                         
])

# Compile your model
model.compile(optimizer="sgd",loss="sparse_categorical_crossentropy",metrics=['accuracy'])

# Fit your model and store the training history in a variable (history) that you can query to plot the training loss, later. 
history = model.fit(train_images_random,train_labels_random, batch_size=25,epochs=30)
# Out:
# Epoch 1/30
# 200/200 [==============================] - 1s 4ms/step - loss: 2.3549 - accuracy: 0.0962
# Epoch 2/30
# 200/200 [==============================] - 1s 4ms/step - loss: 2.3124 - accuracy: 0.1196
# Epoch 3/30
# 200/200 [==============================] - 1s 4ms/step - loss: 2.2842 - accuracy: 0.1346
# Epoch 4/30
# 200/200 [==============================] - 1s 4ms/step - loss: 2.2631 - accuracy: 0.1554
# Epoch 5/30
# 200/200 [==============================] - 1s 4ms/step - loss: 2.2428 - accuracy: 0.1742
# Epoch 6/30
# 200/200 [==============================] - 1s 4ms/step - loss: 2.2209 - accuracy: 0.1826
# Epoch 7/30
# 200/200 [==============================] - 1s 4ms/step - loss: 2.2015 - accuracy: 0.1998
# Epoch 8/30
# 200/200 [==============================] - 1s 4ms/step - loss: 2.1792 - accuracy: 0.2128
# Epoch 9/30
# 200/200 [==============================] - 1s 4ms/step - loss: 2.1581 - accuracy: 0.2396
# Epoch 10/30
# 200/200 [==============================] - 1s 4ms/step - loss: 2.1332 - accuracy: 0.2526
# Epoch 11/30
# 200/200 [==============================] - 1s 4ms/step - loss: 2.1154 - accuracy: 0.2642
# Epoch 12/30
# 200/200 [==============================] - 1s 4ms/step - loss: 2.0923 - accuracy: 0.2834
# Epoch 13/30
# 200/200 [==============================] - 1s 4ms/step - loss: 2.0706 - accuracy: 0.2902
# Epoch 14/30
# 200/200 [==============================] - 1s 4ms/step - loss: 2.0446 - accuracy: 0.3122
# Epoch 15/30
# 200/200 [==============================] - 1s 4ms/step - loss: 2.0183 - accuracy: 0.3238
# Epoch 16/30
# 200/200 [==============================] - 1s 4ms/step - loss: 1.9962 - accuracy: 0.3446
# Epoch 17/30
# 200/200 [==============================] - 1s 4ms/step - loss: 1.9644 - accuracy: 0.3520
# Epoch 18/30
# 200/200 [==============================] - 1s 4ms/step - loss: 1.9433 - accuracy: 0.3680
# Epoch 19/30
# 200/200 [==============================] - 1s 4ms/step - loss: 1.9150 - accuracy: 0.3730
# Epoch 20/30
# 200/200 [==============================] - 1s 4ms/step - loss: 1.8904 - accuracy: 0.3900
# Epoch 21/30
# 200/200 [==============================] - 1s 4ms/step - loss: 1.8612 - accuracy: 0.4026
# Epoch 22/30
# 200/200 [==============================] - 1s 4ms/step - loss: 1.8321 - accuracy: 0.4132
# Epoch 23/30
# 200/200 [==============================] - 1s 4ms/step - loss: 1.8043 - accuracy: 0.4286
# Epoch 24/30
# 200/200 [==============================] - 1s 4ms/step - loss: 1.7770 - accuracy: 0.4372
# Epoch 25/30
# 200/200 [==============================] - 1s 4ms/step - loss: 1.7517 - accuracy: 0.4420
# Epoch 26/30
# 200/200 [==============================] - 1s 4ms/step - loss: 1.7245 - accuracy: 0.4550
# Epoch 27/30
# 200/200 [==============================] - 1s 4ms/step - loss: 1.6990 - accuracy: 0.4614
# Epoch 28/30
# 200/200 [==============================] - 1s 4ms/step - loss: 1.6705 - accuracy: 0.4706
# Epoch 29/30
# 200/200 [==============================] - 1s 4ms/step - loss: 1.6455 - accuracy: 0.4852
# Epoch 30/30
# 200/200 [==============================] - 1s 4ms/step - loss: 1.6157 - accuracy: 0.4966

# %% [markdown]
# Okay, plot the training loss now...

# %%
# Call plot commands here. 
plt.plot(history.history['loss'])
plt.show()
