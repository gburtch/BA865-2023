# %% [markdown]
# #**Detecting Fake Reviews**

# %% [markdown]
# This dataset is the product of research by a few folks in Computer Science: https://aclanthology.org/N13-1053.pdf.

# %%
import tensorflow as tf
from tensorflow import keras
from google.colab import files
import pandas as pd
import io

trip_advisor = pd.read_csv('https://raw.githubusercontent.com/gburtch/BA865-2023/main/Lecture%20Materials/C/dataset/deceptive-opinion.csv')

#uploaded = files.upload()
#trip_advisor = pd.read_csv(io.BytesIO(uploaded['deceptive-opinion.csv']))
trip_advisor.describe(include='all')
# Out:
#        deceptive   hotel  polarity source  \
# count       1600    1600      1600   1600
# unique         2      20         2      3
# top     truthful  conrad  positive  MTurk
# freq         800      80       800    800
#
#                                                      text
# count                                                1600
# unique                                               1596
# top     The Omni was chosen for it's location whichwor...
# freq                                                    2

# %% [markdown]
# We can use some of the Keras utilities to pre-process the text.
#
# *Q: What features should we use for our prediction?*

# %%
import numpy as np
from keras.preprocessing.text import text_to_word_sequence

# The dataset is perfectly balanced, so 50% accuracy will be equivalent to a random guess. 
labels = np.where(trip_advisor['deceptive']=='truthful',0,1)

text = []
for i in range(len(trip_advisor)):
  text.append(text_to_word_sequence(trip_advisor['text'][i])) # This strips punctuation, odd characters, and makes things lower-case.

# %% [markdown]
# This is another pre-processing step, but it's optional.
#
# *Q: What does this code block do?*

# %%
min_freq = 1

word_freq = {}
for review in text:
  for term in review:
    try:
        word_freq[term] = word_freq[term]+1
    except KeyError:
        word_freq[term] = 1

max_freq = max(i for i in word_freq.values())
for i in range(len(text)):
  text[i] = [term for term in text[i] if word_freq[term] >= min_freq & word_freq[term] <= max_freq]

# %% [markdown]
# Here, we are making our integer codings for the text tokens.

# %%
# We declare a set, which we populate from terms from the corpus, one by one. 
# Sets only allow 'unique' values. 
unique_terms = {term for review in text for term in review}
print(f'We have {len(unique_terms)} unique tokens in our dataset.')

# We can then easily make a term-integer dictionary and an integer-term dictionary (for reverse lookup)
word_index = {term: number for number, term in enumerate(unique_terms)}
reverse_index = {number: term for number, term in enumerate(unique_terms)}
# Out:
# We have 10275 unique tokens in our dataset.

# %% [markdown]
# One-hot encoding the text can be done very explicitly now, as a nested loop.

# %%
def vectorize_sequences(sequences, dimension=len(unique_terms)): 
    # Make our blank matrix of 0's to store hot encodings.
    results = np.zeros((len(sequences), dimension))

    # For each observation and element in that observation,
    # Update the blank matrix to a 1 at row obs, column element value.
    for i, sequence in enumerate(sequences):
        for j in sequence:
            results[i, word_index[j]] = 1.
    return results

text_onehot = vectorize_sequences(text)

text_onehot.shape
# Out:
# (1600, 10275)

# %% [markdown]
# Don't forget we have a few other features in the data. It's not just about the review text...

# %%
# One hot encoding the hotels. 
hotel_dict = {hotel : index for index, hotel in enumerate(set(trip_advisor['hotel']))}
hotels = []
for hotel in trip_advisor['hotel']:
  hotels.append(hotel_dict[hotel])

hotels_onehot = keras.utils.to_categorical(np.array(hotels))

# One hot encoding the review source
#source_int = np.where(np.array(trip_advisor['source'])=='MTurk',0,np.where(np.array(trip_advisor['source'])=='TripAdvisor',1,2))
#source_onehot = keras.utils.to_categorical(source_int)

# Binarizing the polarity
polarity_bin = np.where(np.array(trip_advisor['polarity'])=="negative",0,1).reshape(1600,1)

# Last step, we shuffle the data
data_onehot = np.concatenate((labels.reshape(1600,1),text_onehot,hotels_onehot,polarity_bin),axis=1)
np.random.shuffle(data_onehot)

# Then we pull out predictors and labels.
predictors = data_onehot[:,1:]
labels = data_onehot[:,0]

# %% [markdown]
# Now we can fit out model to the resulting data. Once again we have k-fold cross validation here.

# %%
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import random

random.seed(12345)

def build_model():
    model = keras.Sequential([
        layers.BatchNormalization(),
        layers.Dropout(0.4),
        # This is essentially a dense layer that mimics word embedding; we are reducing the one-hot encoded text (10,000+ one-hot tokens) down to 750 latent dimensions.
        layers.Dense(750, activation="linear",kernel_regularizer="l2"),
        layers.Dense(50, activation="relu",kernel_regularizer="l2"),
        layers.Dense(1, activation="sigmoid")
    ])
    model.compile(optimizer="sgd", loss="binary_crossentropy", metrics=["binary_accuracy"])
    return model

model = build_model()

data_train = predictors[:1200]
labels_train = labels[:1200]
data_test = predictors[1200:]
labels_test = labels[1200:]

k = 4
num_validation_samples = len(data_train) // k
num_epochs = 30
batch_sizes = 32
all_loss_histories = []
all_val_loss_histories = []  
all_acc_histories = []
all_val_acc_histories = []

# For each validation fold, we will train a full set of epochs, and store the history. 
for fold in range(k):
    validation_data = data_train[num_validation_samples * fold:
                           num_validation_samples * (fold + 1)]
    validation_targets = labels_train[num_validation_samples * fold:
                           num_validation_samples * (fold + 1)]
    training_data = np.concatenate([
        data_train[:num_validation_samples * fold],
        data_train[num_validation_samples * (fold + 1):]])
    training_targets = np.concatenate([
        labels_train[:num_validation_samples * fold],
        labels_train[num_validation_samples * (fold + 1):]])
    model = build_model()
    history = model.fit(training_data, training_targets, 
                        validation_data = (validation_data,validation_targets), 
                        epochs=num_epochs, batch_size=batch_sizes)
    val_loss_history = history.history['val_loss']
    val_acc_history = history.history['val_binary_accuracy']
    loss_history = history.history['loss']
    acc_history = history.history['binary_accuracy']
    all_val_loss_histories.append(val_loss_history)
    all_loss_histories.append(loss_history)
    all_val_acc_histories.append(val_acc_history)
    all_acc_histories.append(acc_history)
# Out:
# Epoch 1/30
# 29/29 [==============================] - 1s 12ms/step - loss: 15.5602 - binary_accuracy: 0.5344 - val_loss: 15.3949 - val_binary_accuracy: 0.7533
# Epoch 2/30
# 29/29 [==============================] - 0s 5ms/step - loss: 15.1957 - binary_accuracy: 0.7711 - val_loss: 15.1834 - val_binary_accuracy: 0.7933
# Epoch 3/30
# 29/29 [==============================] - 0s 5ms/step - loss: 14.9125 - binary_accuracy: 0.8578 - val_loss: 14.9731 - val_binary_accuracy: 0.8500
# Epoch 4/30
# 29/29 [==============================] - 0s 5ms/step - loss: 14.6853 - binary_accuracy: 0.8922 - val_loss: 14.7711 - val_binary_accuracy: 0.8767
# Epoch 5/30
# 29/29 [==============================] - 0s 5ms/step - loss: 14.4698 - binary_accuracy: 0.9300 - val_loss: 14.5705 - val_binary_accuracy: 0.8733
# Epoch 6/30
# 29/29 [==============================] - 0s 5ms/step - loss: 14.2640 - binary_accuracy: 0.9378 - val_loss: 14.3764 - val_binary_accuracy: 0.8733
# Epoch 7/30
# 29/29 [==============================] - 0s 5ms/step - loss: 14.1005 - binary_accuracy: 0.9322 - val_loss: 14.1845 - val_binary_accuracy: 0.8733
# Epoch 8/30
# 29/29 [==============================] - 0s 5ms/step - loss: 13.9125 - binary_accuracy: 0.9411 - val_loss: 14.0000 - val_binary_accuracy: 0.8800
# Epoch 9/30
# 29/29 [==============================] - 0s 5ms/step - loss: 13.7294 - binary_accuracy: 0.9578 - val_loss: 13.8222 - val_binary_accuracy: 0.8867
# Epoch 10/30
# 29/29 [==============================] - 0s 5ms/step - loss: 13.5508 - binary_accuracy: 0.9656 - val_loss: 13.6513 - val_binary_accuracy: 0.8867
# Epoch 11/30
# 29/29 [==============================] - 0s 5ms/step - loss: 13.3868 - binary_accuracy: 0.9656 - val_loss: 13.4827 - val_binary_accuracy: 0.8933
# Epoch 12/30
# 29/29 [==============================] - 0s 5ms/step - loss: 13.2287 - binary_accuracy: 0.9711 - val_loss: 13.3157 - val_binary_accuracy: 0.8967
# Epoch 13/30
# 29/29 [==============================] - 0s 5ms/step - loss: 13.0612 - binary_accuracy: 0.9744 - val_loss: 13.1613 - val_binary_accuracy: 0.8967
# Epoch 14/30
# 29/29 [==============================] - 0s 5ms/step - loss: 12.9258 - binary_accuracy: 0.9689 - val_loss: 13.0116 - val_binary_accuracy: 0.8933
# Epoch 15/30
# 29/29 [==============================] - 0s 5ms/step - loss: 12.7559 - binary_accuracy: 0.9756 - val_loss: 12.8629 - val_binary_accuracy: 0.9033
# Epoch 16/30
# 29/29 [==============================] - 0s 5ms/step - loss: 12.6113 - binary_accuracy: 0.9856 - val_loss: 12.7190 - val_binary_accuracy: 0.9033
# Epoch 17/30
# 29/29 [==============================] - 0s 5ms/step - loss: 12.4590 - binary_accuracy: 0.9711 - val_loss: 12.5779 - val_binary_accuracy: 0.8933
# Epoch 18/30
# 29/29 [==============================] - 0s 5ms/step - loss: 12.3190 - binary_accuracy: 0.9800 - val_loss: 12.4389 - val_binary_accuracy: 0.8900
# Epoch 19/30
# 29/29 [==============================] - 0s 5ms/step - loss: 12.1707 - binary_accuracy: 0.9822 - val_loss: 12.3047 - val_binary_accuracy: 0.8900
# Epoch 20/30
# 29/29 [==============================] - 0s 5ms/step - loss: 12.0385 - binary_accuracy: 0.9767 - val_loss: 12.1745 - val_binary_accuracy: 0.8900
# Epoch 21/30
# 29/29 [==============================] - 0s 5ms/step - loss: 11.8831 - binary_accuracy: 0.9878 - val_loss: 12.0414 - val_binary_accuracy: 0.8833
# Epoch 22/30
# 29/29 [==============================] - 0s 5ms/step - loss: 11.7558 - binary_accuracy: 0.9822 - val_loss: 11.9097 - val_binary_accuracy: 0.8867
# Epoch 23/30
# 29/29 [==============================] - 0s 5ms/step - loss: 11.6230 - binary_accuracy: 0.9833 - val_loss: 11.7821 - val_binary_accuracy: 0.8667
# Epoch 24/30
# 29/29 [==============================] - 0s 5ms/step - loss: 11.4838 - binary_accuracy: 0.9844 - val_loss: 11.6552 - val_binary_accuracy: 0.8767
# Epoch 25/30
# 29/29 [==============================] - 0s 5ms/step - loss: 11.3490 - binary_accuracy: 0.9833 - val_loss: 11.5316 - val_binary_accuracy: 0.8700
# Epoch 26/30
# 29/29 [==============================] - 0s 5ms/step - loss: 11.2222 - binary_accuracy: 0.9767 - val_loss: 11.4100 - val_binary_accuracy: 0.8700
# Epoch 27/30
# 29/29 [==============================] - 0s 5ms/step - loss: 11.0782 - binary_accuracy: 0.9889 - val_loss: 11.2853 - val_binary_accuracy: 0.8700
# Epoch 28/30
# 29/29 [==============================] - 0s 5ms/step - loss: 10.9676 - binary_accuracy: 0.9767 - val_loss: 11.1750 - val_binary_accuracy: 0.8700
# Epoch 29/30
# 29/29 [==============================] - 0s 5ms/step - loss: 10.8360 - binary_accuracy: 0.9856 - val_loss: 11.0610 - val_binary_accuracy: 0.8567
# Epoch 30/30
# 29/29 [==============================] - 0s 6ms/step - loss: 10.7008 - binary_accuracy: 0.9900 - val_loss: 10.9418 - val_binary_accuracy: 0.8567
# Epoch 1/30
# 29/29 [==============================] - 1s 12ms/step - loss: 15.5354 - binary_accuracy: 0.5700 - val_loss: 15.3982 - val_binary_accuracy: 0.6567
# Epoch 2/30
# 29/29 [==============================] - 0s 5ms/step - loss: 15.1480 - binary_accuracy: 0.8144 - val_loss: 15.1927 - val_binary_accuracy: 0.7533
# Epoch 3/30
# 29/29 [==============================] - 0s 5ms/step - loss: 14.8921 - binary_accuracy: 0.8644 - val_loss: 14.9952 - val_binary_accuracy: 0.7667
# Epoch 4/30
# 29/29 [==============================] - 0s 5ms/step - loss: 14.6536 - binary_accuracy: 0.9156 - val_loss: 14.7933 - val_binary_accuracy: 0.8000
# Epoch 5/30
# 29/29 [==============================] - 0s 5ms/step - loss: 14.4458 - binary_accuracy: 0.9389 - val_loss: 14.6058 - val_binary_accuracy: 0.7967
# Epoch 6/30
# 29/29 [==============================] - 0s 5ms/step - loss: 14.2392 - binary_accuracy: 0.9456 - val_loss: 14.4163 - val_binary_accuracy: 0.8200
# Epoch 7/30
# 29/29 [==============================] - 0s 5ms/step - loss: 14.0579 - binary_accuracy: 0.9567 - val_loss: 14.2326 - val_binary_accuracy: 0.8233
# Epoch 8/30
# 29/29 [==============================] - 0s 5ms/step - loss: 13.8903 - binary_accuracy: 0.9478 - val_loss: 14.0535 - val_binary_accuracy: 0.8333
# Epoch 9/30
# 29/29 [==============================] - 0s 5ms/step - loss: 13.7143 - binary_accuracy: 0.9567 - val_loss: 13.8810 - val_binary_accuracy: 0.8333
# Epoch 10/30
# 29/29 [==============================] - 0s 5ms/step - loss: 13.5491 - binary_accuracy: 0.9578 - val_loss: 13.7142 - val_binary_accuracy: 0.8333
# Epoch 11/30
# 29/29 [==============================] - 0s 5ms/step - loss: 13.3720 - binary_accuracy: 0.9656 - val_loss: 13.5511 - val_binary_accuracy: 0.8367
# Epoch 12/30
# 29/29 [==============================] - 0s 5ms/step - loss: 13.2225 - binary_accuracy: 0.9678 - val_loss: 13.3971 - val_binary_accuracy: 0.8333
# Epoch 13/30
# 29/29 [==============================] - 0s 5ms/step - loss: 13.0621 - binary_accuracy: 0.9656 - val_loss: 13.2501 - val_binary_accuracy: 0.8300
# Epoch 14/30
# 29/29 [==============================] - 0s 5ms/step - loss: 12.8979 - binary_accuracy: 0.9722 - val_loss: 13.1000 - val_binary_accuracy: 0.8333
# Epoch 15/30
# 29/29 [==============================] - 0s 5ms/step - loss: 12.7485 - binary_accuracy: 0.9744 - val_loss: 12.9571 - val_binary_accuracy: 0.8300
# Epoch 16/30
# 29/29 [==============================] - 0s 5ms/step - loss: 12.5866 - binary_accuracy: 0.9822 - val_loss: 12.8240 - val_binary_accuracy: 0.8333
# Epoch 17/30
# 29/29 [==============================] - 0s 5ms/step - loss: 12.4500 - binary_accuracy: 0.9811 - val_loss: 12.6939 - val_binary_accuracy: 0.8300
# Epoch 18/30
# 29/29 [==============================] - 0s 5ms/step - loss: 12.2975 - binary_accuracy: 0.9811 - val_loss: 12.5641 - val_binary_accuracy: 0.8300
# Epoch 19/30
# 29/29 [==============================] - 0s 6ms/step - loss: 12.1571 - binary_accuracy: 0.9800 - val_loss: 12.4380 - val_binary_accuracy: 0.8267
# Epoch 20/30
# 29/29 [==============================] - 0s 5ms/step - loss: 12.0249 - binary_accuracy: 0.9756 - val_loss: 12.3034 - val_binary_accuracy: 0.8367
# Epoch 21/30
# 29/29 [==============================] - 0s 5ms/step - loss: 11.8788 - binary_accuracy: 0.9822 - val_loss: 12.1848 - val_binary_accuracy: 0.8167
# Epoch 22/30
# 29/29 [==============================] - 0s 5ms/step - loss: 11.7507 - binary_accuracy: 0.9789 - val_loss: 12.0602 - val_binary_accuracy: 0.8133
# Epoch 23/30
# 29/29 [==============================] - 0s 5ms/step - loss: 11.6157 - binary_accuracy: 0.9856 - val_loss: 11.9422 - val_binary_accuracy: 0.8033
# Epoch 24/30
# 29/29 [==============================] - 0s 6ms/step - loss: 11.4706 - binary_accuracy: 0.9867 - val_loss: 11.8253 - val_binary_accuracy: 0.8000
# Epoch 25/30
# 29/29 [==============================] - 0s 5ms/step - loss: 11.3236 - binary_accuracy: 0.9878 - val_loss: 11.7094 - val_binary_accuracy: 0.8033
# Epoch 26/30
# 29/29 [==============================] - 0s 5ms/step - loss: 11.2029 - binary_accuracy: 0.9878 - val_loss: 11.5910 - val_binary_accuracy: 0.8000
# Epoch 27/30
# 29/29 [==============================] - 0s 5ms/step - loss: 11.0799 - binary_accuracy: 0.9800 - val_loss: 11.4756 - val_binary_accuracy: 0.8000
# Epoch 28/30
# 29/29 [==============================] - 0s 5ms/step - loss: 10.9502 - binary_accuracy: 0.9889 - val_loss: 11.3557 - val_binary_accuracy: 0.8000
# Epoch 29/30
# 29/29 [==============================] - 0s 5ms/step - loss: 10.8243 - binary_accuracy: 0.9800 - val_loss: 11.2395 - val_binary_accuracy: 0.8000
# Epoch 30/30
# 29/29 [==============================] - 0s 5ms/step - loss: 10.6980 - binary_accuracy: 0.9878 - val_loss: 11.1224 - val_binary_accuracy: 0.7967
# Epoch 1/30
# 29/29 [==============================] - 2s 12ms/step - loss: 15.5408 - binary_accuracy: 0.5644 - val_loss: 15.4042 - val_binary_accuracy: 0.6933
# Epoch 2/30
# 29/29 [==============================] - 0s 5ms/step - loss: 15.1775 - binary_accuracy: 0.7956 - val_loss: 15.1936 - val_binary_accuracy: 0.7800
# Epoch 3/30
# 29/29 [==============================] - 0s 6ms/step - loss: 14.9020 - binary_accuracy: 0.8844 - val_loss: 14.9876 - val_binary_accuracy: 0.8067
# Epoch 4/30
# 29/29 [==============================] - 0s 5ms/step - loss: 14.6827 - binary_accuracy: 0.9011 - val_loss: 14.7861 - val_binary_accuracy: 0.8233
# Epoch 5/30
# 29/29 [==============================] - 0s 5ms/step - loss: 14.4730 - binary_accuracy: 0.9267 - val_loss: 14.5853 - val_binary_accuracy: 0.8333
# Epoch 6/30
# 29/29 [==============================] - 0s 5ms/step - loss: 14.2779 - binary_accuracy: 0.9300 - val_loss: 14.3903 - val_binary_accuracy: 0.8367
# Epoch 7/30
# 29/29 [==============================] - 0s 5ms/step - loss: 14.0791 - binary_accuracy: 0.9444 - val_loss: 14.2014 - val_binary_accuracy: 0.8533
# Epoch 8/30
# 29/29 [==============================] - 0s 5ms/step - loss: 13.8969 - binary_accuracy: 0.9589 - val_loss: 14.0178 - val_binary_accuracy: 0.8533
# Epoch 9/30
# 29/29 [==============================] - 0s 6ms/step - loss: 13.7249 - binary_accuracy: 0.9622 - val_loss: 13.8386 - val_binary_accuracy: 0.8533
# Epoch 10/30
# 29/29 [==============================] - 0s 5ms/step - loss: 13.5567 - binary_accuracy: 0.9667 - val_loss: 13.6637 - val_binary_accuracy: 0.8700
# Epoch 11/30
# 29/29 [==============================] - 0s 5ms/step - loss: 13.4022 - binary_accuracy: 0.9622 - val_loss: 13.4948 - val_binary_accuracy: 0.8733
# Epoch 12/30
# 29/29 [==============================] - 0s 5ms/step - loss: 13.2302 - binary_accuracy: 0.9711 - val_loss: 13.3322 - val_binary_accuracy: 0.8700
# Epoch 13/30
# 29/29 [==============================] - 0s 5ms/step - loss: 13.0662 - binary_accuracy: 0.9800 - val_loss: 13.1756 - val_binary_accuracy: 0.8733
# Epoch 14/30
# 29/29 [==============================] - 0s 5ms/step - loss: 12.9065 - binary_accuracy: 0.9811 - val_loss: 13.0241 - val_binary_accuracy: 0.8767
# Epoch 15/30
# 29/29 [==============================] - 0s 5ms/step - loss: 12.7589 - binary_accuracy: 0.9678 - val_loss: 12.8727 - val_binary_accuracy: 0.8733
# Epoch 16/30
# 29/29 [==============================] - 0s 5ms/step - loss: 12.6152 - binary_accuracy: 0.9767 - val_loss: 12.7264 - val_binary_accuracy: 0.8667
# Epoch 17/30
# 29/29 [==============================] - 0s 5ms/step - loss: 12.4512 - binary_accuracy: 0.9878 - val_loss: 12.5873 - val_binary_accuracy: 0.8733
# Epoch 18/30
# 29/29 [==============================] - 0s 5ms/step - loss: 12.3094 - binary_accuracy: 0.9844 - val_loss: 12.4453 - val_binary_accuracy: 0.8700
# Epoch 19/30
# 29/29 [==============================] - 0s 5ms/step - loss: 12.1790 - binary_accuracy: 0.9778 - val_loss: 12.3119 - val_binary_accuracy: 0.8700
# Epoch 20/30
# 29/29 [==============================] - 0s 5ms/step - loss: 12.0343 - binary_accuracy: 0.9789 - val_loss: 12.1852 - val_binary_accuracy: 0.8733
# Epoch 21/30
# 29/29 [==============================] - 0s 5ms/step - loss: 11.8819 - binary_accuracy: 0.9889 - val_loss: 12.0534 - val_binary_accuracy: 0.8700
# Epoch 22/30
# 29/29 [==============================] - 0s 5ms/step - loss: 11.7440 - binary_accuracy: 0.9911 - val_loss: 11.9211 - val_binary_accuracy: 0.8667
# Epoch 23/30
# 29/29 [==============================] - 0s 5ms/step - loss: 11.6131 - binary_accuracy: 0.9856 - val_loss: 11.8009 - val_binary_accuracy: 0.8533
# Epoch 24/30
# 29/29 [==============================] - 0s 6ms/step - loss: 11.4844 - binary_accuracy: 0.9800 - val_loss: 11.6710 - val_binary_accuracy: 0.8500
# Epoch 25/30
# 29/29 [==============================] - 0s 5ms/step - loss: 11.3378 - binary_accuracy: 0.9889 - val_loss: 11.5492 - val_binary_accuracy: 0.8600
# Epoch 26/30
# 29/29 [==============================] - 0s 5ms/step - loss: 11.2166 - binary_accuracy: 0.9844 - val_loss: 11.4252 - val_binary_accuracy: 0.8467
# Epoch 27/30
# 29/29 [==============================] - 0s 5ms/step - loss: 11.0865 - binary_accuracy: 0.9856 - val_loss: 11.3020 - val_binary_accuracy: 0.8433
# Epoch 28/30
# 29/29 [==============================] - 0s 5ms/step - loss: 10.9594 - binary_accuracy: 0.9867 - val_loss: 11.1834 - val_binary_accuracy: 0.8400
# Epoch 29/30
# 29/29 [==============================] - 0s 5ms/step - loss: 10.8355 - binary_accuracy: 0.9856 - val_loss: 11.0651 - val_binary_accuracy: 0.8400
# Epoch 30/30
# 29/29 [==============================] - 0s 5ms/step - loss: 10.7211 - binary_accuracy: 0.9800 - val_loss: 10.9406 - val_binary_accuracy: 0.8467
# Epoch 1/30
# 29/29 [==============================] - 1s 12ms/step - loss: 15.5331 - binary_accuracy: 0.5600 - val_loss: 15.4014 - val_binary_accuracy: 0.6833
# Epoch 2/30
# 29/29 [==============================] - 0s 5ms/step - loss: 15.1849 - binary_accuracy: 0.7856 - val_loss: 15.1972 - val_binary_accuracy: 0.7300
# Epoch 3/30
# 29/29 [==============================] - 0s 5ms/step - loss: 14.9250 - binary_accuracy: 0.8589 - val_loss: 14.9943 - val_binary_accuracy: 0.7867
# Epoch 4/30
# 29/29 [==============================] - 0s 5ms/step - loss: 14.6825 - binary_accuracy: 0.9133 - val_loss: 14.7914 - val_binary_accuracy: 0.7900
# Epoch 5/30
# 29/29 [==============================] - 0s 5ms/step - loss: 14.4661 - binary_accuracy: 0.9356 - val_loss: 14.5951 - val_binary_accuracy: 0.8067
# Epoch 6/30
# 29/29 [==============================] - 0s 5ms/step - loss: 14.2623 - binary_accuracy: 0.9389 - val_loss: 14.4004 - val_binary_accuracy: 0.8133
# Epoch 7/30
# 29/29 [==============================] - 0s 5ms/step - loss: 14.0845 - binary_accuracy: 0.9422 - val_loss: 14.2126 - val_binary_accuracy: 0.8367
# Epoch 8/30
# 29/29 [==============================] - 0s 5ms/step - loss: 13.8975 - binary_accuracy: 0.9589 - val_loss: 14.0318 - val_binary_accuracy: 0.8367
# Epoch 9/30
# 29/29 [==============================] - 0s 5ms/step - loss: 13.7236 - binary_accuracy: 0.9544 - val_loss: 13.8554 - val_binary_accuracy: 0.8467
# Epoch 10/30
# 29/29 [==============================] - 0s 6ms/step - loss: 13.5642 - binary_accuracy: 0.9611 - val_loss: 13.6841 - val_binary_accuracy: 0.8633
# Epoch 11/30
# 29/29 [==============================] - 0s 5ms/step - loss: 13.3749 - binary_accuracy: 0.9800 - val_loss: 13.5165 - val_binary_accuracy: 0.8633
# Epoch 12/30
# 29/29 [==============================] - 0s 5ms/step - loss: 13.2187 - binary_accuracy: 0.9789 - val_loss: 13.3562 - val_binary_accuracy: 0.8633
# Epoch 13/30
# 29/29 [==============================] - 0s 5ms/step - loss: 13.0631 - binary_accuracy: 0.9644 - val_loss: 13.2023 - val_binary_accuracy: 0.8567
# Epoch 14/30
# 29/29 [==============================] - 0s 5ms/step - loss: 12.9081 - binary_accuracy: 0.9767 - val_loss: 13.0484 - val_binary_accuracy: 0.8600
# Epoch 15/30
# 29/29 [==============================] - 0s 5ms/step - loss: 12.7661 - binary_accuracy: 0.9733 - val_loss: 12.9075 - val_binary_accuracy: 0.8633
# Epoch 16/30
# 29/29 [==============================] - 0s 6ms/step - loss: 12.6092 - binary_accuracy: 0.9744 - val_loss: 12.7639 - val_binary_accuracy: 0.8700
# Epoch 17/30
# 29/29 [==============================] - 0s 5ms/step - loss: 12.4499 - binary_accuracy: 0.9878 - val_loss: 12.6209 - val_binary_accuracy: 0.8700
# Epoch 18/30
# 29/29 [==============================] - 0s 5ms/step - loss: 12.3185 - binary_accuracy: 0.9733 - val_loss: 12.4881 - val_binary_accuracy: 0.8567
# Epoch 19/30
# 29/29 [==============================] - 0s 5ms/step - loss: 12.1707 - binary_accuracy: 0.9778 - val_loss: 12.3518 - val_binary_accuracy: 0.8533
# Epoch 20/30
# 29/29 [==============================] - 0s 5ms/step - loss: 12.0076 - binary_accuracy: 0.9900 - val_loss: 12.2159 - val_binary_accuracy: 0.8600
# Epoch 21/30
# 29/29 [==============================] - 0s 5ms/step - loss: 11.8875 - binary_accuracy: 0.9800 - val_loss: 12.0835 - val_binary_accuracy: 0.8600
# Epoch 22/30
# 29/29 [==============================] - 0s 6ms/step - loss: 11.7463 - binary_accuracy: 0.9856 - val_loss: 11.9592 - val_binary_accuracy: 0.8600
# Epoch 23/30
# 29/29 [==============================] - 0s 6ms/step - loss: 11.6064 - binary_accuracy: 0.9878 - val_loss: 11.8348 - val_binary_accuracy: 0.8567
# Epoch 24/30
# 29/29 [==============================] - 0s 6ms/step - loss: 11.4927 - binary_accuracy: 0.9711 - val_loss: 11.7039 - val_binary_accuracy: 0.8500
# Epoch 25/30
# 29/29 [==============================] - 0s 5ms/step - loss: 11.3354 - binary_accuracy: 0.9878 - val_loss: 11.5845 - val_binary_accuracy: 0.8433
# Epoch 26/30
# 29/29 [==============================] - 0s 6ms/step - loss: 11.2242 - binary_accuracy: 0.9800 - val_loss: 11.4582 - val_binary_accuracy: 0.8467
# Epoch 27/30
# 29/29 [==============================] - 0s 6ms/step - loss: 11.0924 - binary_accuracy: 0.9789 - val_loss: 11.3353 - val_binary_accuracy: 0.8467
# Epoch 28/30
# 29/29 [==============================] - 0s 6ms/step - loss: 10.9542 - binary_accuracy: 0.9822 - val_loss: 11.2113 - val_binary_accuracy: 0.8533
# Epoch 29/30
# 29/29 [==============================] - 0s 6ms/step - loss: 10.8252 - binary_accuracy: 0.9867 - val_loss: 11.0919 - val_binary_accuracy: 0.8533
# Epoch 30/30
# 29/29 [==============================] - 0s 5ms/step - loss: 10.7025 - binary_accuracy: 0.9867 - val_loss: 10.9626 - val_binary_accuracy: 0.8500

# %% [markdown]
# *Q: What does 'x' represent in these iterators?*
#
# *Q: Can anyone explain in simple words what this code is doing?*

# %%
average_loss_history = [np.mean([x[i] for x in all_loss_histories]) for i in range(num_epochs)]
average_val_loss_history = [np.mean([x[i] for x in all_val_loss_histories]) for i in range(num_epochs)]
average_acc_history = [np.mean([x[i] for x in all_acc_histories]) for i in range(num_epochs)]
average_val_acc_history = [np.mean([x[i] for x in all_val_acc_histories]) for i in range(num_epochs)]

# %% [markdown]
# Here we plot the cross-validated performance:

# %%
# Plot validation performance. 
plt.plot(average_loss_history,c='r')
plt.plot(average_val_loss_history,c='b')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(['Training Loss','Validation Loss'])
plt.show()

plt.plot(average_acc_history,c="r",linestyle="dashed")
plt.plot(average_val_acc_history,c='b',linestyle="dashed")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(['Training Accuracy','Validation Accuracy'])
